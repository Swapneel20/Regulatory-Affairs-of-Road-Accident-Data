# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/KIIT/Downloads/Regulatory Affairs of Road Accident Data 2020 India.csv")

# %%
df
# Out:
#      Million Plus Cities   Cause category        Cause Subcategory  \
# 0                   Agra  Traffic Control  Flashing Signal/Blinker
# 1                   Agra  Traffic Control  Flashing Signal/Blinker
# 2                   Agra  Traffic Control  Flashing Signal/Blinker
# 3                   Agra  Traffic Control  Flashing Signal/Blinker
# 4                   Agra  Traffic Control  Flashing Signal/Blinker
# ...                  ...              ...                      ...
# 9545               Vizaq          Weather              Sunny/Clear
# 9546               Vizaq          Weather              Sunny/Clear
# 9547               Vizaq          Weather              Sunny/Clear
# 9548               Vizaq          Weather              Sunny/Clear
# 9549               Vizaq          Weather              Sunny/Clear
#
#             Outcome of Incident   Count
# 0            Greviously Injured     0.0
# 1                  Minor Injury     0.0
# ...

# %%
df.shape
# Out:
# (9550, 5)

# %%
df.size
# Out:
# 47750

# %%
df.head()
# Out:
#   Million Plus Cities   Cause category        Cause Subcategory  \
# 0                Agra  Traffic Control  Flashing Signal/Blinker
# 1                Agra  Traffic Control  Flashing Signal/Blinker
# 2                Agra  Traffic Control  Flashing Signal/Blinker
# 3                Agra  Traffic Control  Flashing Signal/Blinker
# 4                Agra  Traffic Control  Flashing Signal/Blinker
#
#          Outcome of Incident  Count
# 0         Greviously Injured    0.0
# 1               Minor Injury    0.0
# 2             Persons Killed    0.0
# 3              Total Injured    0.0
# 4  Total number of Accidents    0.0

# %%
df.tail()
# Out:
#      Million Plus Cities Cause category Cause Subcategory  \
# 9545               Vizaq        Weather       Sunny/Clear
# 9546               Vizaq        Weather       Sunny/Clear
# 9547               Vizaq        Weather       Sunny/Clear
# 9548               Vizaq        Weather       Sunny/Clear
# 9549               Vizaq        Weather       Sunny/Clear
#
#             Outcome of Incident   Count
# 9545         Greviously Injured   561.0
# 9546               Minor Injury   252.0
# 9547             Persons Killed   176.0
# 9548  Total number of Accidents  1207.0
# 9549              Total Injured   813.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9550 entries, 0 to 9549
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Million Plus Cities  9550 non-null   object
#  1   Cause category       9550 non-null   object
#  2   Cause Subcategory    9550 non-null   object
#  3   Outcome of Incident  9550 non-null   object
#  4   Count                9547 non-null   float64
# dtypes: float64(1), object(4)
# memory usage: 373.2+ KB

# %%
df.columns
# Out:
# Index(['Million Plus Cities', 'Cause category', 'Cause Subcategory',
#        'Outcome of Incident', 'Count'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Million Plus Cities    0
# Cause category         0
# Cause Subcategory      0
# Outcome of Incident    0
# Count                  3
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Million Plus Cities   Cause category        Cause Subcategory  \
# 0                   Agra  Traffic Control  Flashing Signal/Blinker
# 1                   Agra  Traffic Control  Flashing Signal/Blinker
# 2                   Agra  Traffic Control  Flashing Signal/Blinker
# 3                   Agra  Traffic Control  Flashing Signal/Blinker
# 4                   Agra  Traffic Control  Flashing Signal/Blinker
# ...                  ...              ...                      ...
# 9545               Vizaq          Weather              Sunny/Clear
# 9546               Vizaq          Weather              Sunny/Clear
# 9547               Vizaq          Weather              Sunny/Clear
# 9548               Vizaq          Weather              Sunny/Clear
# 9549               Vizaq          Weather              Sunny/Clear
#
#             Outcome of Incident   Count
# 0            Greviously Injured     0.0
# 1                  Minor Injury     0.0
# ...

# %%
df["Million Plus Cities"].value_counts()
# Out:
# Million Plus Cities
# Agra                    191
# Patna                   191
# Kollam                  191
# Kota                    191
# Lucknow                 191
# Ludhiana                191
# Madurai                 191
# Mallapuram              191
# Meerut                  191
# Mumbai                  191
# Nagpur                  191
# Nashik                  191
# Pune                    191
# Ahmedabad               191
# Raipur                  191
# Rajkot                  191
# Srinagar                191
# Surat                   191
# Thiruvanthapuram        191
# Thrissur                191
# Tiruchirapalli          191
# Vadodra                 191
# Varanasi                191
# Vijaywada city          191
# Kolkata                 191
# Kochi                   191
# Khozikode               191
# Kanpur                  191
# Allahabad(Prayagraj)    191
# Amritsar                191
# Asansol Durgapur        191
# Aurangabad              191
# ...

# %%
df["Cause category"].value_counts()
# Out:
# Cause category
# Road Features               2000
# Impacting Vehicle/Object    1800
# Traffic Control             1500
# Junction                    1500
# Traffic Violation           1500
# Weather                     1250
# Name: count, dtype: int64

# %%
df["Cause Subcategory"].value_counts()
# Out:
# Cause Subcategory
# Others                                              1450
# Flashing Signal/Blinker                              250
# Over                                                 250
# Rainy                                                250
# Hail/Sleet                                           250
# Foggy and Misty                                      250
# Straight Road                                        250
# Steep Grade                                          250
# Pot Holes                                            250
# Ongoing Road Works/Under Construction                250
# Curved Road                                          250
# Bridge                                               250
# Use of Mobile Phone                                  250
# Culvert                                              250
# Jumping Red Light                                    250
# Four arm Junction                                    250
# ...

# %%
df["Outcome of Incident"].value_counts()
# Out:
# Outcome of Incident
# Greviously Injured           2000
# Minor Injury                 2000
# Persons Killed               2000
# Total number of Accidents    2000
# Total Injured                1550
# Name: count, dtype: int64

# %%
df=pd.read_csv("C:/Users/KIIT/Downloads/Regulatory Affairs of Road Accident Data 2020 India.csv",index_col="Million Plus Cities")

# %%
df
# Out:
#                       Cause category        Cause Subcategory  \
# Million Plus Cities
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# ...                              ...                      ...
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
#
#                            Outcome of Incident   Count
# Million Plus Cities
# Agra                        Greviously Injured     0.0
# Agra                              Minor Injury     0.0
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                         Cause category        Cause Subcategory  \
# Million Plus Cities
# Vizaq                          Weather              Sunny/Clear
# Vizaq                         Junction                        Y
# Vizaq                Traffic Violation                     Over
# Vizaq                Traffic Violation                     Over
# Vizaq                Traffic Violation                   Others
# ...                                ...                      ...
# Agra                 Traffic Violation      Use of Mobile Phone
# Agra                 Traffic Violation      Use of Mobile Phone
# Agra                 Traffic Violation      Use of Mobile Phone
# Agra                 Traffic Violation      Use of Mobile Phone
# Agra                   Traffic Control  Flashing Signal/Blinker
#
#                            Outcome of Incident  Count
# Million Plus Cities
# Vizaq                            Total Injured  813.0
# ...

# %%
df
# Out:
#                       Cause category        Cause Subcategory  \
# Million Plus Cities
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# Agra                 Traffic Control  Flashing Signal/Blinker
# ...                              ...                      ...
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
# Vizaq                        Weather              Sunny/Clear
#
#                            Outcome of Incident   Count
# Million Plus Cities
# Agra                        Greviously Injured     0.0
# Agra                              Minor Injury     0.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(data=df,x="Cause Subcategory")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df,x="Cause category")
plt.xticks(rotation=90)
plt.show()
